# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from functools import reduce

# %%
# 2019
data_2019 = pd.read_csv("data/국민여가활동_2019.csv")
data_2019 = data_2019.rename(columns={
    "AREA_NM": "지역명",
    "TY_ACCTO_CLTUR_ART_VIEWNG_ACT_CO" : "유형별문화예술관람활동수",
    "TY_ACCTO_CLTUR_ART_PARTCPTN_ACT_CO" : "유형별문화예술참여활동수",
    "TY_ACCTO_SPORTS_VIEWNG_ACT_CO" : "유형별스포츠관람활동수",
    "TY_ACCTO_SPORTS_PARTCPTN_ACT_CO" : "유형별스포츠참여활동수",
    "TY_ACCTO_VIEWNG_ACT_CO" : "유형별관람활동수",
    "TY_ACCTO_HOBBY_RCRT_ACT_CO" : "유형별취미오락활동수",
    "TY_ACCTO_REST_ACT_CO" : "유형별휴식활동수",
    "TY_ACCTO_SCT_ND_ETC_ACT_CO" : "유형별사회및기타활동수",
    "INDVDL_TV_WTCHNG_CO" : "개인TV시청수",
    "INDVDL_INTNT_ACT_CO": "개인인터넷활동수",
    "INDVDL_CNTCT_ACT_CO" : "개인연락활동수",
    "INDVDL_WLK_ACT_CO" : "개인산책활동수",
    "INDVDL_GAME_ACT_CO" : "개인게임활동수",
    "INDVDL_MVM_CO" : "개인운동수",
    "INDVDL_MUSIC_LSTN_CO" : "개인음악듣기수",
    "INDVDL_PET_ACT_CO" : "개인반려동물활동수",
    "INDVDL_SPORTS_INDRCT_VIEWNG_CO" : "개인스포츠간접관람수",
    "INDVDL_READ_ACT_CO" : "개인독서활동수",
    "INDVDL_SHOPNG_BRDOT_CO" : "개인쇼핑외식수",
    "INDVDL_NAP_CO" : "개인낮잠수",
    "INDVDL_CMC_READ_CO" : "개인만화독서수",
    "INDVDL_CLIMD_ACT_CO" : "개인등산활동수",
    "INDVDL_RADIO_LSTN_CO" : "개인라디오듣기수",
    "INDVDL_NWSPR_MZN_READ_CO" : "개인신문잡지독서수",
    "INDVDL_BATH_ACT_CO" : "개인목욕활동수",
    "INDVDL_GOLF_ACT_CO" : "개인골프활동수",
    "INDVDL_NTHG_ACT_CO" : "개인무활동수",
    "INDVDL_LANG_TCHNLGY_CRTFCT_ACQS_ACT_CO" : "개인언어기술자격증취득활동수",
    "INDVDL_MOVIE_VIEWNG_CO" : "개인영화관람수",
    "INDVDL_CYBER_SPORTS_VIEWNG_CO" : "개인사이버스포츠관람수",
    "INDVDL_FART_ACT_CO" : "개인미술활동수",
    "INDVDL_GMBL_LTTR_PRCHS_CO": "개인도박복권구매수",
    "INDVDL_BLRDRM_ACT_CO" : "개인당구장활동수",
    "INDVDL_BCYCL_ACT_CO" : "개인자전거활동수",
    "INDVDL_LVLH_CRFT_ACT_CO": "개인생활공예활동수",
    "INDVDL_PHOTO_PHT_CO" : "개인사진촬영수",
    "INDVDL_CLUB_GROUP_CO" : "개인동호회그룹수",
    "INDVDL_NATURE_ATRCT_VIEWNG_CO" : "개인자연명소관람수",
    "INDVDL_SPORTS_VIEWNG_ACT_CO" : "개인스포츠관람활동수",
    "INDVDL_DSPY_VIEWNG_CO" : "개인전시관람수",
    "INDVDL_FSHNG_ACT_CO" : "개인낚시활동수",
    "INDVDL_COLCT_ACT_CO" : "개인수집활동수",
    "INDVDL_SNGRUM_VISIT_CO" : "개인노래방방문수",
    "INDVDL_WRTNG_READ_DSCSN_ACT_CO" : "개인필기독서토론활동수",
    "INDVDL_SCT_VLNTWK_ACT_CO" : "개인사회봉사활동수",
    "INDVDL_BTY_ACT_CO" : "개인미용활동수",
    "INDVDL_FAMILY_ACQNTNC_VISIT_CO" : "개인가족지인방문수",
    "INDVDL_TRDIT_ART_LRN_ACT_CO" : "개인전통예술학습활동수",
    "INDVDL_CLTUR_RELICS_VISIT_CO" : "개인문화유적방문수",
    "INDVDL_THEMEPARK_AMSMTPRK_ZOO_BTNCGDN_VISIT_CO" : "개인테마파크놀이공원동물원식물원방문수",
    "INDVDL_ETC_LSR_ACT_CO" : "개인기타레저활동수",
    "INDVDL_MUSEUM_VIEWNG_CO" : "개인박물관관람수",
    "INDVDL_DMSTC_CAMPING_ACT_CO" : "개인국내캠핑활동수",
    "INDVDL_AREA_FSTVL_PARTCPT_CO" : "개인지역축제참가수",
    "INDVDL_GROUP_ACT_CO" : "개인그룹활동수",
    "INDVDL_TRDIT_ART_PBLPRFR_VIEWNG_CO" : "개인전통예술공연관람수",
    "INDVDL_TOUR_SHIP_BRDNG_CO" : "개인여행배탑승수",
    "INDVDL_OVSEA_TOUR_CO" : "개인해외여행수",
    "INDVDL_LTRTR_EVENT_PARTCPTN_CO" : "개인문학행사참여수"
})
data_2019 = data_2019[data_2019.지역명 == "서울"].drop(["지역명", "HMPG_ADDR", 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63',
       'Unnamed: 64', 'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 67',
       'Unnamed: 68', 'Unnamed: 69', 'Unnamed: 70', 'Unnamed: 71',
       'Unnamed: 72', 'Unnamed: 73', 'Unnamed: 74', 'Unnamed: 75',
       'Unnamed: 76', 'Unnamed: 77', 'Unnamed: 78', 'Unnamed: 79',
       'Unnamed: 80', 'Unnamed: 81', 'Unnamed: 82'], axis = 1)
data_2019 = data_2019.T.reset_index().rename(columns = {"index" : "Category",
                                      0 : "Value"})
data_2019.loc[data_2019.Value == '-',"Value"] = 0
data_2019.Value = [float(i) for i in data_2019.Value]
data_2019
# Out:
#                Category  Value
# 0          유형별문화예술관람활동수    0.3
# 1          유형별문화예술참여활동수    0.5
# 2           유형별스포츠관람활동수    3.3
# 3           유형별스포츠참여활동수    6.1
# 4              유형별관람활동수    0.4
# 5            유형별취미오락활동수   28.9
# 6              유형별휴식활동수   53.9
# 7           유형별사회및기타활동수    6.6
# 8               개인TV시청수   38.3
# 9              개인인터넷활동수   18.9
# 10              개인연락활동수    5.2
# 11              개인산책활동수    4.4
# 12              개인게임활동수    2.9
# 13                개인운동수    2.4
# 14              개인음악듣기수    4.8
# 15            개인반려동물활동수    1.7
# 16           개인스포츠간접관람수    2.7
# 17              개인독서활동수    0.8
# 18              개인쇼핑외식수    0.4
# 19                개인낮잠수    0.6
# 20              개인만화독서수    0.1
# 21              개인등산활동수    0.6
# 22             개인라디오듣기수    0.2
# 23            개인신문잡지독서수    0.1
# 24              개인목욕활동수    0.3
# 25              개인골프활동수    0.3
# 26               개인무활동수    0.6
# 27       개인언어기술자격증취득활동수    0.6
# 28              개인영화관람수    0.1
# ...

# %%
# 2020
data_2020 = pd.read_csv("data/국민여가활동_2020.csv")
data_2020 = data_2020.rename(columns={
    "AREA_NM": "지역명",
    "TY_ACCTO_CLTUR_ART_VIEWNG_ACT_CO" : "유형별문화예술관람활동수",
    "TY_ACCTO_CLTUR_ART_PARTCPTN_ACT_CO" : "유형별문화예술참여활동수",
    "TY_ACCTO_SPORTS_VIEWNG_ACT_CO" : "유형별스포츠관람활동수",
    "TY_ACCTO_SPORTS_PARTCPTN_ACT_CO" : "유형별스포츠참여활동수",
    "TY_ACCTO_VIEWNG_ACT_CO" : "유형별관람활동수",
    "TY_ACCTO_HOBBY_RCRT_ACT_CO" : "유형별취미오락활동수",
    "TY_ACCTO_REST_ACT_CO" : "유형별휴식활동수",
    "TY_ACCTO_SCT_ND_ETC_ACT_CO" : "유형별사회및기타활동수",
    "INDVDL_TV_WTCHNG_CO" : "개인TV시청수",
    "INDVDL_INTNT_ACT_CO": "개인인터넷활동수",
    "INDVDL_CNTCT_ACT_CO" : "개인연락활동수",
    "INDVDL_WLK_ACT_CO" : "개인산책활동수",
    "INDVDL_GAME_ACT_CO" : "개인게임활동수",
    "INDVDL_MVM_CO" : "개인운동수",
    "INDVDL_MUSIC_LSTN_CO" : "개인음악듣기수",
    "INDVDL_PET_ACT_CO" : "개인반려동물활동수",
    "INDVDL_SPORTS_INDRCT_VIEWNG_CO" : "개인스포츠간접관람수",
    "INDVDL_READ_ACT_CO" : "개인독서활동수",
    "INDVDL_SHOPNG_BRDOT_CO" : "개인쇼핑외식수",
    "INDVDL_NAP_CO" : "개인낮잠수",
    "INDVDL_CMC_READ_CO" : "개인만화독서수",
    "INDVDL_CLIMD_ACT_CO" : "개인등산활동수",
    "INDVDL_RADIO_LSTN_CO" : "개인라디오듣기수",
    "INDVDL_NWSPR_MZN_READ_CO" : "개인신문잡지독서수",
    "INDVDL_BATH_ACT_CO" : "개인목욕활동수",
    "INDVDL_GOLF_ACT_CO" : "개인골프활동수",
    "INDVDL_NTHG_ACT_CO" : "개인무활동수",
    "INDVDL_LANG_TCHNLGY_CRTFCT_ACQS_ACT_CO" : "개인언어기술자격증취득활동수",
    "INDVDL_MOVIE_VIEWNG_CO" : "개인영화관람수",
    "INDVDL_CYBER_SPORTS_VIEWNG_CO" : "개인사이버스포츠관람수",
    "INDVDL_FART_ACT_CO" : "개인미술활동수",
    "INDVDL_GMBL_LTTR_PRCHS_CO": "개인도박복권구매수",
    "INDVDL_BLRDRM_ACT_CO" : "개인당구장활동수",
    "INDVDL_BCYCL_ACT_CO" : "개인자전거활동수",
    "INDVDL_LVLH_CRFT_ACT_CO": "개인생활공예활동수",
    "INDVDL_PHOTO_PHT_CO" : "개인사진촬영수",
    "INDVDL_CLUB_GROUP_CO" : "개인동호회그룹수",
    "INDVDL_NATURE_ATRCT_VIEWNG_CO" : "개인자연명소관람수",
    "INDVDL_SPORTS_VIEWNG_ACT_CO" : "개인스포츠관람활동수",
    "INDVDL_DSPY_VIEWNG_CO" : "개인전시관람수",
    "INDVDL_FSHNG_ACT_CO" : "개인낚시활동수",
    "INDVDL_COLCT_ACT_CO" : "개인수집활동수",
    "INDVDL_SNGRUM_VISIT_CO" : "개인노래방방문수",
    "INDVDL_WRTNG_READ_DSCSN_ACT_CO" : "개인필기독서토론활동수",
    "INDVDL_SCT_VLNTWK_ACT_CO" : "개인사회봉사활동수",
    "INDVDL_BTY_ACT_CO" : "개인미용활동수",
    "INDVDL_FAMILY_ACQNTNC_VISIT_CO" : "개인가족지인방문수",
    "INDVDL_TRDIT_ART_LRN_ACT_CO" : "개인전통예술학습활동수",
    "INDVDL_CLTUR_RELICS_VISIT_CO" : "개인문화유적방문수",
    "INDVDL_THEMEPARK_AMSMTPRK_ZOO_BTNCGDN_VISIT_CO" : "개인테마파크놀이공원동물원식물원방문수",
    "INDVDL_ETC_LSR_ACT_CO" : "개인기타레저활동수",
    "INDVDL_MUSEUM_VIEWNG_CO" : "개인박물관관람수",
    "INDVDL_DMSTC_CAMPING_ACT_CO" : "개인국내캠핑활동수",
    "INDVDL_AREA_FSTVL_PARTCPT_CO" : "개인지역축제참가수",
    "INDVDL_GROUP_ACT_CO" : "개인그룹활동수",
    "INDVDL_TRDIT_ART_PBLPRFR_VIEWNG_CO" : "개인전통예술공연관람수",
    "INDVDL_TOUR_SHIP_BRDNG_CO" : "개인여행배탑승수",
    "INDVDL_OVSEA_TOUR_CO" : "개인해외여행수",
    "INDVDL_LTRTR_EVENT_PARTCPTN_CO" : "개인문학행사참여수"
})
data_2020 = data_2020[data_2020.지역명 == "서울"].drop(["지역명", "HMPG_ADDR"], axis = 1)
data_2020 = data_2020.T.reset_index().rename(columns = {"index" : "Category",
                                      0 : "Value"})
data_2020.loc[data_2020.Value.isnull(),"Value"] = 0
data_2020
# Out:
#                Category  Value
# 0          유형별문화예술관람활동수    4.1
# 1          유형별문화예술참여활동수    1.1
# 2           유형별스포츠관람활동수    2.1
# 3           유형별스포츠참여활동수   12.1
# 4              유형별관람활동수    1.8
# 5            유형별취미오락활동수   22.3
# 6              유형별휴식활동수   50.3
# 7           유형별사회및기타활동수    6.3
# 8               개인TV시청수   29.7
# 9              개인인터넷활동수    5.5
# 10              개인연락활동수    2.5
# 11              개인산책활동수   10.7
# 12              개인게임활동수    6.0
# 13                개인운동수    3.9
# 14              개인음악듣기수    0.9
# 15            개인반려동물활동수    0.8
# 16           개인스포츠간접관람수    1.7
# 17              개인독서활동수    1.6
# 18              개인쇼핑외식수    1.2
# 19                개인낮잠수    0.2
# 20              개인만화독서수    0.5
# 21              개인등산활동수    3.0
# 22             개인라디오듣기수    0.3
# 23            개인신문잡지독서수    0.1
# 24              개인목욕활동수    0.4
# 25              개인골프활동수    0.9
# 26               개인무활동수    0.2
# 27       개인언어기술자격증취득활동수    0.3
# 28              개인영화관람수    3.1
# ...

# %%
data_2020.loc[data_2020.Value.isnull(),"Value"]
# Out:
# 29   NaN
# 55   NaN
# 56   NaN
# 58   NaN
# Name: Value, dtype: float64

# %%
# 2021
data_2021 = pd.read_csv("data/국민여가활동_2021.csv")
data_2021 = data_2021.rename(columns={
    "AREA_NM": "지역명",
    "TY_ACCTO_CLTUR_ART_VIEWNG_ACT_CO" : "유형별문화예술관람활동수",
    "TY_ACCTO_CLTUR_ART_PARTCPTN_ACT_CO" : "유형별문화예술참여활동수",
    "TY_ACCTO_SPORTS_VIEWNG_ACT_CO" : "유형별스포츠관람활동수",
    "TY_ACCTO_SPORTS_PARTCPTN_ACT_CO" : "유형별스포츠참여활동수",
    "TY_ACCTO_VIEWNG_ACT_CO" : "유형별관람활동수",
    "TY_ACCTO_HOBBY_RCRT_ACT_CO" : "유형별취미오락활동수",
    "TY_ACCTO_REST_ACT_CO" : "유형별휴식활동수",
    "TY_ACCTO_SCT_ND_ETC_ACT_CO" : "유형별사회및기타활동수",
    "INDVDL_TV_WTCHNG_CO" : "개인TV시청수",
    "INDVDL_INTNT_ACT_CO": "개인인터넷활동수",
    "INDVDL_CNTCT_ACT_CO" : "개인연락활동수",
    "INDVDL_WLK_ACT_CO" : "개인산책활동수",
    "INDVDL_GAME_ACT_CO" : "개인게임활동수",
    "INDVDL_MVM_CO" : "개인운동수",
    "INDVDL_MUSIC_LSTN_CO" : "개인음악듣기수",
    "INDVDL_PET_ACT_CO" : "개인반려동물활동수",
    "INDVDL_SPORTS_INDRCT_VIEWNG_CO" : "개인스포츠간접관람수",
    "INDVDL_READ_ACT_CO" : "개인독서활동수",
    "INDVDL_SHOPNG_BRDOT_CO" : "개인쇼핑외식수",
    "INDVDL_NAP_CO" : "개인낮잠수",
    "INDVDL_CMC_READ_CO" : "개인만화독서수",
    "INDVDL_CLIMD_ACT_CO" : "개인등산활동수",
    "INDVDL_RADIO_LSTN_CO" : "개인라디오듣기수",
    "INDVDL_NWSPR_MZN_READ_CO" : "개인신문잡지독서수",
    "INDVDL_BATH_ACT_CO" : "개인목욕활동수",
    "INDVDL_GOLF_ACT_CO" : "개인골프활동수",
    "INDVDL_NTHG_ACT_CO" : "개인무활동수",
    "INDVDL_LANG_TCHNLGY_CRTFCT_ACQS_ACT_CO" : "개인언어기술자격증취득활동수",
    "INDVDL_MOVIE_VIEWNG_CO" : "개인영화관람수",
    "INDVDL_CYBER_SPORTS_VIEWNG_CO" : "개인사이버스포츠관람수",
    "INDVDL_FART_ACT_CO" : "개인미술활동수",
    "INDVDL_GMBL_LTTR_PRCHS_CO": "개인도박복권구매수",
    "INDVDL_BLRDRM_ACT_CO" : "개인당구장활동수",
    "INDVDL_BCYCL_ACT_CO" : "개인자전거활동수",
    "INDVDL_LVLH_CRFT_ACT_CO": "개인생활공예활동수",
    "INDVDL_PHOTO_PHT_CO" : "개인사진촬영수",
    "INDVDL_CLUB_GROUP_CO" : "개인동호회그룹수",
    "INDVDL_NATURE_ATRCT_VIEWNG_CO" : "개인자연명소관람수",
    "INDVDL_SPORTS_VIEWNG_ACT_CO" : "개인스포츠관람활동수",
    "INDVDL_DSPY_VIEWNG_CO" : "개인전시관람수",
    "INDVDL_FSHNG_ACT_CO" : "개인낚시활동수",
    "INDVDL_COLCT_ACT_CO" : "개인수집활동수",
    "INDVDL_SNGRUM_VISIT_CO" : "개인노래방방문수",
    "INDVDL_WRTNG_READ_DSCSN_ACT_CO" : "개인필기독서토론활동수",
    "INDVDL_SCT_VLNTWK_ACT_CO" : "개인사회봉사활동수",
    "INDVDL_BTY_ACT_CO" : "개인미용활동수",
    "INDVDL_FAMILY_ACQNTNC_VISIT_CO" : "개인가족지인방문수",
    "INDVDL_TRDIT_ART_LRN_ACT_CO" : "개인전통예술학습활동수",
    "INDVDL_CLTUR_RELICS_VISIT_CO" : "개인문화유적방문수",
    "INDVDL_THEMEPARK_AMSMTPRK_ZOO_BTNCGDN_VISIT_CO" : "개인테마파크놀이공원동물원식물원방문수",
    "INDVDL_ETC_LSR_ACT_CO" : "개인기타레저활동수",
    "INDVDL_MUSEUM_VIEWNG_CO" : "개인박물관관람수",
    "INDVDL_DMSTC_CAMPING_ACT_CO" : "개인국내캠핑활동수",
    "INDVDL_AREA_FSTVL_PARTCPT_CO" : "개인지역축제참가수",
    "INDVDL_GROUP_ACT_CO" : "개인그룹활동수",
    "INDVDL_TRDIT_ART_PBLPRFR_VIEWNG_CO" : "개인전통예술공연관람수",
    "INDVDL_TOUR_SHIP_BRDNG_CO" : "개인여행배탑승수",
    "INDVDL_OVSEA_TOUR_CO" : "개인해외여행수",
    "INDVDL_LTRTR_EVENT_PARTCPTN_CO" : "개인문학행사참여수"
})
data_2021 = data_2021[data_2021.지역명 == "서울"].drop(["지역명", "HMPG_ADDR"], axis = 1)
data_2021 = data_2021.T.reset_index().rename(columns = {"index" : "Category",
                                      0 : "Value"})
data_2021
# Out:
#                Category  Value
# 0          유형별문화예술관람활동수   80.9
# 1          유형별문화예술참여활동수   20.0
# 2           유형별스포츠관람활동수   59.6
# 3           유형별스포츠참여활동수   84.7
# 4              유형별관람활동수  185.6
# 5            유형별취미오락활동수  379.0
# 6              유형별휴식활동수  395.0
# 7           유형별사회및기타활동수  257.9
# 8               개인TV시청수   88.0
# 9              개인인터넷활동수   52.0
# 10              개인연락활동수   74.4
# 11              개인산책활동수   80.6
# 12              개인게임활동수   26.5
# 13                개인운동수   17.1
# 14              개인음악듣기수   38.8
# 15            개인반려동물활동수   11.7
# 16           개인스포츠간접관람수   43.8
# 17              개인독서활동수   23.4
# 18              개인쇼핑외식수   78.4
# 19                개인낮잠수   46.2
# 20              개인만화독서수   11.8
# 21              개인등산활동수   27.2
# 22             개인라디오듣기수   13.4
# 23            개인신문잡지독서수   13.5
# 24              개인목욕활동수   31.0
# 25              개인골프활동수    4.7
# 26               개인무활동수   17.7
# 27       개인언어기술자격증취득활동수    7.9
# 28              개인영화관람수   51.0
# ...

# %%
# 2022
data_2022 = pd.read_csv("data/국민여가활동_2022.csv")
data_2022 = data_2022.rename(columns={
    "AREA_NM": "지역명",
    "TY_ACCTO_CLTUR_ART_VIEWNG_ACT_CO" : "유형별문화예술관람활동수",
    "TY_ACCTO_CLTUR_ART_PARTCPTN_ACT_CO" : "유형별문화예술참여활동수",
    "TY_ACCTO_SPORTS_VIEWNG_ACT_CO" : "유형별스포츠관람활동수",
    "TY_ACCTO_SPORTS_PARTCPTN_ACT_CO" : "유형별스포츠참여활동수",
    "TY_ACCTO_VIEWNG_ACT_CO" : "유형별관람활동수",
    "TY_ACCTO_HOBBY_RCRT_ACT_CO" : "유형별취미오락활동수",
    "TY_ACCTO_REST_ACT_CO" : "유형별휴식활동수",
    "TY_ACCTO_SCT_ND_ETC_ACT_CO" : "유형별사회및기타활동수",
    "INDVDL_TV_WTCHNG_CO" : "개인TV시청수",
    "INDVDL_INTNT_ACT_CO": "개인인터넷활동수",
    "INDVDL_CNTCT_ACT_CO" : "개인연락활동수",
    "INDVDL_WLK_ACT_CO" : "개인산책활동수",
    "INDVDL_GAME_ACT_CO" : "개인게임활동수",
    "INDVDL_MVM_CO" : "개인운동수",
    "INDVDL_MUSIC_LSTN_CO" : "개인음악듣기수",
    "INDVDL_PET_ACT_CO" : "개인반려동물활동수",
    "INDVDL_SPORTS_INDRCT_VIEWNG_CO" : "개인스포츠간접관람수",
    "INDVDL_READ_ACT_CO" : "개인독서활동수",
    "INDVDL_SHOPNG_BRDOT_CO" : "개인쇼핑외식수",
    "INDVDL_NAP_CO" : "개인낮잠수",
    "INDVDL_CMC_READ_CO" : "개인만화독서수",
    "INDVDL_CLIMD_ACT_CO" : "개인등산활동수",
    "INDVDL_RADIO_LSTN_CO" : "개인라디오듣기수",
    "INDVDL_NWSPR_MZN_READ_CO" : "개인신문잡지독서수",
    "INDVDL_BATH_ACT_CO" : "개인목욕활동수",
    "INDVDL_GOLF_ACT_CO" : "개인골프활동수",
    "INDVDL_NTHG_ACT_CO" : "개인무활동수",
    "INDVDL_LANG_TCHNLGY_CRTFCT_ACQS_ACT_CO" : "개인언어기술자격증취득활동수",
    "INDVDL_MOVIE_VIEWNG_CO" : "개인영화관람수",
    "INDVDL_CYBER_SPORTS_VIEWNG_CO" : "개인사이버스포츠관람수",
    "INDVDL_FART_ACT_CO" : "개인미술활동수",
    "INDVDL_GMBL_LTTR_PRCHS_CO": "개인도박복권구매수",
    "INDVDL_BLRDRM_ACT_CO" : "개인당구장활동수",
    "INDVDL_BCYCL_ACT_CO" : "개인자전거활동수",
    "INDVDL_LVLH_CRFT_ACT_CO": "개인생활공예활동수",
    "INDVDL_PHOTO_PHT_CO" : "개인사진촬영수",
    "INDVDL_CLUB_GROUP_CO" : "개인동호회그룹수",
    "INDVDL_NATURE_ATRCT_VIEWNG_CO" : "개인자연명소관람수",
    "INDVDL_SPORTS_VIEWNG_ACT_CO" : "개인스포츠관람활동수",
    "INDVDL_DSPY_VIEWNG_CO" : "개인전시관람수",
    "INDVDL_FSHNG_ACT_CO" : "개인낚시활동수",
    "INDVDL_COLCT_ACT_CO" : "개인수집활동수",
    "INDVDL_SNGRUM_VISIT_CO" : "개인노래방방문수",
    "INDVDL_WRTNG_READ_DSCSN_ACT_CO" : "개인필기독서토론활동수",
    "INDVDL_SCT_VLNTWK_ACT_CO" : "개인사회봉사활동수",
    "INDVDL_BTY_ACT_CO" : "개인미용활동수",
    "INDVDL_FAMILY_ACQNTNC_VISIT_CO" : "개인가족지인방문수",
    "INDVDL_TRDIT_ART_LRN_ACT_CO" : "개인전통예술학습활동수",
    "INDVDL_CLTUR_RELICS_VISIT_CO" : "개인문화유적방문수",
    "INDVDL_THEMEPARK_AMSMTPRK_ZOO_BTNCGDN_VISIT_CO" : "개인테마파크놀이공원동물원식물원방문수",
    "INDVDL_ETC_LSR_ACT_CO" : "개인기타레저활동수",
    "INDVDL_MUSEUM_VIEWNG_CO" : "개인박물관관람수",
    "INDVDL_DMSTC_CAMPING_ACT_CO" : "개인국내캠핑활동수",
    "INDVDL_AREA_FSTVL_PARTCPT_CO" : "개인지역축제참가수",
    "INDVDL_GROUP_ACT_CO" : "개인그룹활동수",
    "INDVDL_TRDIT_ART_PBLPRFR_VIEWNG_CO" : "개인전통예술공연관람수",
    "INDVDL_TOUR_SHIP_BRDNG_CO" : "개인여행배탑승수",
    "INDVDL_OVSEA_TOUR_CO" : "개인해외여행수",
    "INDVDL_LTRTR_EVENT_PARTCPTN_CO" : "개인문학행사참여수"
})
data_2022 = data_2022[data_2022.지역명 == "서울"].drop(["지역명", "HMPG_ADDR"], axis = 1)
data_2022 = data_2022.T.reset_index().rename(columns = {"index" : "Category",
                                      0 : "Value"})
data_2022
# Out:
#                Category  Value
# 0          유형별문화예술관람활동수   80.2
# 1          유형별문화예술참여활동수   24.7
# 2           유형별스포츠관람활동수   54.1
# 3           유형별스포츠참여활동수   80.7
# 4              유형별관람활동수  157.2
# 5            유형별취미오락활동수  336.2
# 6              유형별휴식활동수  341.6
# 7           유형별사회및기타활동수  222.0
# 8               개인TV시청수   80.6
# 9              개인인터넷활동수   45.3
# 10              개인연락활동수   56.7
# 11              개인산책활동수   66.8
# 12              개인게임활동수   21.5
# 13                개인운동수   14.1
# 14              개인음악듣기수   37.7
# 15            개인반려동물활동수    9.7
# 16           개인스포츠간접관람수   40.0
# 17              개인독서활동수   16.2
# 18              개인쇼핑외식수   66.6
# 19                개인낮잠수   36.6
# 20              개인만화독서수    9.4
# 21              개인등산활동수   21.9
# 22             개인라디오듣기수    8.7
# 23            개인신문잡지독서수    9.9
# 24              개인목욕활동수   37.3
# 25              개인골프활동수    6.4
# 26               개인무활동수    7.7
# 27       개인언어기술자격증취득활동수    6.5
# 28              개인영화관람수   47.1
# ...

# %%
data_2019_2 = data_2019[data_2019["Category"].str.contains("유형별")]
data_2019_2 = data_2019_2.sort_values(by = "Value", ascending = False)
data_2020_2 = data_2020[data_2020["Category"].str.contains("유형별")]
data_2020_2 = data_2020_2.sort_values(by = "Value", ascending = False)
data_2021_2 = data_2021[data_2021["Category"].str.contains("유형별")]
data_2021_2 = data_2021_2.sort_values(by = "Value", ascending = False)
data_2022_2 = data_2022[data_2022["Category"].str.contains("유형별")]
data_2022_2 = data_2022_2.sort_values(by = "Value", ascending = False)
'''
plt.figure(figsize=(20,15))
sns.barplot(y="Category", x="Value", data=data_2)
plt.rc('ytick', labelsize=15) 
'''
data_2022_2
# Out:
#        Category  Value
# 6      유형별휴식활동수  341.6
# 5    유형별취미오락활동수  336.2
# 7   유형별사회및기타활동수  222.0
# 4      유형별관람활동수  157.2
# 3   유형별스포츠참여활동수   80.7
# 0  유형별문화예술관람활동수   80.2
# 2   유형별스포츠관람활동수   54.1
# 1  유형별문화예술참여활동수   24.7

# %%
data_2019_2.Category = [s.replace("유형별", "") for s in data_2019_2.Category]
data_2019_2.Category = [s.replace("활동수", "") for s in data_2019_2.Category]
data_2020_2.Category = [s.replace("유형별", "") for s in data_2020_2.Category]
data_2020_2.Category = [s.replace("활동수", "") for s in data_2020_2.Category]
data_2021_2.Category = [s.replace("유형별", "") for s in data_2021_2.Category]
data_2021_2.Category = [s.replace("활동수", "") for s in data_2021_2.Category]
data_2022_2.Category = [s.replace("유형별", "") for s in data_2022_2.Category]
data_2022_2.Category = [s.replace("활동수", "") for s in data_2022_2.Category]

# %%
from matplotlib import font_manager, rc
# font_manager.findSystemFonts(fontpaths = None, fontext = "ttf")
font_path  = "C:\Windows\Fonts\malgun.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)
fig, axes = plt.subplots(2,2, constrained_layout=True)
sns.set_style("white")

# 2019
sns.barplot(x="Category", y="Value", data=data_2019_2, ci = None, ax=axes[0][0])
axes[0][0].set_xlabel("활동명", fontsize = 8)
axes[0][0].set_ylabel("활동수", fontsize = 8)
axes[0][0].tick_params(axis="x", labelsize=8, rotation = 45) 
axes[0][0].tick_params(axis="y", labelsize=8) 
axes[0][0].set_title("유형별 활동 - 2019", fontsize = 12)

# 2020
sns.barplot(x="Category", y="Value", data=data_2020_2, ci = None, ax=axes[0][1])
axes[0][1].set_xlabel("활동명", fontsize = 8)
axes[0][1].set_ylabel("활동수", fontsize = 8)
axes[0][1].tick_params(axis="x", labelsize=8, rotation = 45) 
axes[0][1].tick_params(axis="y", labelsize=8) 
axes[0][1].set_title("유형별 활동 - 2020", fontsize = 12)

# 2021
sns.barplot(x="Category", y="Value", data=data_2021_2, ci = None, ax=axes[1][0])
axes[1][0].set_xlabel("활동명", fontsize = 8)
axes[1][0].set_ylabel("활동수", fontsize = 8)
axes[1][0].tick_params(axis="x", labelsize=8, rotation = 45) 
axes[1][0].tick_params(axis="y", labelsize=8) 
axes[1][0].set_title("유형별 활동 - 2021", fontsize = 12)

# 미디어
sns.barplot(x="Category", y="Value", data=data_2021_2, ci = None, ax=axes[1][1])
axes[1][1].set_xlabel("활동명", fontsize = 8)
axes[1][1].set_ylabel("활동수", fontsize = 8)
axes[1][1].tick_params(axis="x", labelsize=8, rotation = 45) 
axes[1][1].tick_params(axis="y", labelsize=8) 
axes[1][1].set_title("유형별 활동 - 2022", fontsize = 12)


fig.tight_layout()
# Out:
# C:\Users\whfhr\AppData\Local\Temp\ipykernel_15620\3681600690.py:42: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   fig.tight_layout()

# %%
df = [data_2019_2, data_2020_2, data_2021_2, data_2022_2]
data_2 = reduce(lambda left, right: pd.merge(left, right, on='Category'), df)
data_2.columns = ["Category","2019", "2020", "2021", "2022"]
data_2 = pd.melt(data_2, id_vars=['Category'], value_vars=['2019', '2020', '2021', '2022'])
data_2 = data_2.rename(columns = {"variable" : "Year"})
# Out:
# C:\Users\whfhr\AppData\Local\Temp\ipykernel_15620\196898377.py:2: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Value_x'} in the result is deprecated and will raise a MergeError in a future version.
#   data_2 = reduce(lambda left, right: pd.merge(left, right, on='Category'), df)

# %%
font_path  = "C:\Windows\Fonts\malgun.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

fig = plt.figure(figsize=(20,10))
sns.lineplot(x="Year", y="value",hue = "Category", data = data_2, 
             marker='o', linewidth = 3)
plt.legend(fontsize = 16, loc = 'best' )
plt.xlabel("연도", fontsize = 16)
plt.ylabel("활동수", fontsize = 16)
plt.rc('ytick', labelsize=15) 
plt.rc('xtick', labelsize=15) 
plt.title("유형별 국민여가활동수", fontsize = 23)
# Out:
# Text(0.5, 1.0, '유형별 국민여가활동수')

# %%
# 휴식활동
data_2019_rest = data_2019[(data_2019.Category == "개인TV시청수") | 
                (data_2019.Category == "개인산책활동수") | (data_2019.Category == "개인음악듣기수") |
                (data_2019.Category == "개인낮잠수") |(data_2019.Category == "개인라디오듣기수") | 
                (data_2019.Category == "개인신문잡지독서수") | (data_2019.Category == "개인목욕활동수") | 
                (data_2019.Category == "개인무활동수")] 
data_2020_rest = data_2020[(data_2020.Category == "개인TV시청수") | 
                (data_2020.Category == "개인산책활동수") | (data_2020.Category == "개인음악듣기수") |
                (data_2020.Category == "개인낮잠수") |(data_2020.Category == "개인라디오듣기수") | 
                (data_2020.Category == "개인신문잡지독서수") | (data_2020.Category == "개인목욕활동수") | 
                (data_2020.Category == "개인무활동수")] 
data_2021_rest = data_2021[(data_2021.Category == "개인TV시청수") | 
                (data_2021.Category == "개인산책활동수") | (data_2021.Category == "개인음악듣기수") |
                (data_2021.Category == "개인낮잠수") |(data_2021.Category == "개인라디오듣기수") | 
                (data_2021.Category == "개인신문잡지독서수") | (data_2021.Category == "개인목욕활동수") | 
                (data_2021.Category == "개인무활동수")] 
data_2022_rest = data_2022[(data_2022.Category == "개인TV시청수") | 
                (data_2022.Category == "개인산책활동수") | (data_2022.Category == "개인음악듣기수") |
                (data_2022.Category == "개인낮잠수") |(data_2022.Category == "개인라디오듣기수") | 
                (data_2022.Category == "개인신문잡지독서수") | (data_2022.Category == "개인목욕활동수") | 
                (data_2022.Category == "개인무활동수")]

# %%
data_2019_rest.Category = [s.replace("개인", "") for s in data_2019_rest.Category]
data_2019_rest.Category = [s.replace("수", "") for s in data_2019_rest.Category]
data_2019_rest.Category = [s.replace("활동", "") for s in data_2019_rest.Category]
data_2020_rest.Category = [s.replace("개인", "") for s in data_2020_rest.Category]
data_2020_rest.Category = [s.replace("수", "") for s in data_2020_rest.Category]
data_2020_rest.Category = [s.replace("활동", "") for s in data_2020_rest.Category]
data_2021_rest.Category = [s.replace("개인", "") for s in data_2021_rest.Category]
data_2021_rest.Category = [s.replace("수", "") for s in data_2021_rest.Category]
data_2021_rest.Category = [s.replace("활동", "") for s in data_2021_rest.Category]
data_2022_rest.Category = [s.replace("개인", "") for s in data_2022_rest.Category]
data_2022_rest.Category = [s.replace("수", "") for s in data_2022_rest.Category]
data_2022_rest.Category = [s.replace("활동", "") for s in data_2022_rest.Category]
# Out:
# C:\Users\whfhr\AppData\Local\Temp\ipykernel_15620\3521266553.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2019_rest.Category = [s.replace("개인", "") for s in data_2019_rest.Category]
# C:\Users\whfhr\AppData\Local\Temp\ipykernel_15620\3521266553.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2019_rest.Category = [s.replace("수", "") for s in data_2019_rest.Category]
# C:\Users\whfhr\AppData\Local\Temp\ipykernel_15620\3521266553.py:3: SettingWithCopyWarning:
# ...

# %%
font_path  = "C:\Windows\Fonts\malgun.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)
fig, axes = plt.subplots(2,2, constrained_layout=True)
sns.set_style("white")

# 2019
sns.barplot(x="Value", y="Category", data=data_2019_rest, ci = None, ax=axes[0][0])
axes[0][0].set_xlabel("활동수", fontsize = 8)
axes[0][0].set_ylabel("활동명", fontsize = 8)
axes[0][0].tick_params(axis="x", labelsize=8) 
axes[0][0].tick_params(axis="y", labelsize=8) 
axes[0][0].set_title("소극적 활동 - 2019", fontsize = 12)

# 2020
sns.barplot(x="Value", y="Category", data=data_2020_rest, ci = None, ax=axes[0][1])
axes[0][1].set_xlabel("활동수", fontsize = 8)
axes[0][1].set_ylabel("활동명", fontsize = 8)
axes[0][1].tick_params(axis="x", labelsize=8) 
axes[0][1].tick_params(axis="y", labelsize=8) 
axes[0][1].set_title("소극적 활동 - 2020", fontsize = 12)

# 2021
sns.barplot(x="Value", y="Category", data=data_2021_rest, ci = None, ax=axes[1][0])
axes[1][0].set_xlabel("활동수", fontsize = 8)
axes[1][0].set_ylabel("활동명", fontsize = 8)
axes[1][0].tick_params(axis="x", labelsize=8) 
axes[1][0].tick_params(axis="y", labelsize=8) 
axes[1][0].set_title("소극적 활동 - 2021", fontsize = 12)

# 미디어
sns.barplot(x="Value", y="Category", data=data_2022_rest, ci = None, ax=axes[1][1])
axes[1][1].set_xlabel("활동수", fontsize = 8)
axes[1][1].set_ylabel("활동명", fontsize = 8)
axes[1][1].tick_params(axis="x", labelsize=8) 
axes[1][1].tick_params(axis="y", labelsize=8) 
axes[1][1].set_title("소극적 활동 - 2022", fontsize = 12)


fig.tight_layout()
# Out:
# C:\Users\whfhr\AppData\Local\Temp\ipykernel_15620\4266920547.py:40: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   fig.tight_layout()

# %%
df = [data_2019_rest, data_2020_rest, data_2021_rest, data_2022_rest]
data_rest = reduce(lambda left, right: pd.merge(left, right, on='Category'), df)
data_rest.columns = ["Category","2019", "2020", "2021", "2022"]
data_rest = pd.melt(data_rest, id_vars=['Category'], value_vars=['2019', '2020', '2021', '2022'])
data_rest = data_rest.rename(columns = {"variable" : "Year"})
# Out:
# C:\Users\whfhr\AppData\Local\Temp\ipykernel_15620\4134969665.py:2: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Value_x'} in the result is deprecated and will raise a MergeError in a future version.
#   data_rest = reduce(lambda left, right: pd.merge(left, right, on='Category'), df)

# %%
font_path  = "C:\Windows\Fonts\malgun.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

fig = plt.figure(figsize=(20,10))
sns.lineplot(x="Year", y="value",hue = "Category", data = data_rest, 
             marker='o', linewidth = 3)
plt.legend(fontsize = 16, loc = 'best' )
plt.xlabel("연도", fontsize = 16)
plt.ylabel("활동수", fontsize = 16)
plt.rc('ytick', labelsize=15) 
plt.rc('xtick', labelsize=15) 
plt.title("국민여가활동 - 휴식", fontsize = 23)
# Out:
# Text(0.5, 1.0, '국민여가활동 - 휴식')

# %%
# 스포츠활동
data_2019_sports = data_2019[(data_2019.Category == "개인운동수") | 
                (data_2019.Category == "개인스포츠간접관람수") | (data_2019.Category == "개인골프활동수") |
                (data_2019.Category == "개인사이버스포츠관람수") |(data_2019.Category == "개인당구장활동수") | 
                (data_2019.Category == "개인자전거활동수") | (data_2019.Category == "개인스포츠관람활동수") | 
                (data_2019.Category == "개인기타레저활동수")] 
data_2020_sports = data_2020[(data_2020.Category == "개인운동수") | 
                (data_2020.Category == "개인스포츠간접관람수") | (data_2020.Category == "개인골프활동수") |
                (data_2020.Category == "개인사이버스포츠관람수") |(data_2020.Category == "개인당구장활동수") | 
                (data_2020.Category == "개인자전거활동수") | (data_2020.Category == "개인스포츠관람활동수") | 
                (data_2020.Category == "개인기타레저활동수")] 
data_2021_sports = data_2019[(data_2021.Category == "개인운동수") | 
                (data_2021.Category == "개인스포츠간접관람수") | (data_2021.Category == "개인골프활동수") |
                (data_2021.Category == "개인사이버스포츠관람수") |(data_2021.Category == "개인당구장활동수") | 
                (data_2021.Category == "개인자전거활동수") | (data_2021.Category == "개인스포츠관람활동수") | 
                (data_2021.Category == "개인기타레저활동수")] 
data_2022_sports = data_2022[(data_2022.Category == "개인운동수") | 
                (data_2022.Category == "개인스포츠간접관람수") | (data_2022.Category == "개인골프활동수") |
                (data_2022.Category == "개인사이버스포츠관람수") |(data_2022.Category == "개인당구장활동수") | 
                (data_2022.Category == "개인자전거활동수") | (data_2022.Category == "개인스포츠관람활동수") | 
                (data_2022.Category == "개인기타레저활동수")]

# %%
data_2019_sports.Category = [s.replace("개인", "") for s in data_2019_sports.Category]
data_2019_sports.Category = [s.replace("수", "") for s in data_2019_sports.Category]
data_2019_sports.Category = [s.replace("활동", "") for s in data_2019_sports.Category]
data_2020_sports.Category = [s.replace("개인", "") for s in data_2020_sports.Category]
data_2020_sports.Category = [s.replace("수", "") for s in data_2020_sports.Category]
data_2020_sports.Category = [s.replace("활동", "") for s in data_2020_sports.Category]
data_2021_sports.Category = [s.replace("개인", "") for s in data_2021_sports.Category]
data_2021_sports.Category = [s.replace("수", "") for s in data_2021_sports.Category]
data_2021_sports.Category = [s.replace("활동", "") for s in data_2021_sports.Category]
data_2022_sports.Category = [s.replace("개인", "") for s in data_2022_sports.Category]
data_2022_sports.Category = [s.replace("수", "") for s in data_2022_sports.Category]
data_2022_sports.Category = [s.replace("활동", "") for s in data_2022_sports.Category]
# Out:
# C:\Users\whfhr\AppData\Local\Temp\ipykernel_15620\2917215930.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2019_sports.Category = [s.replace("개인", "") for s in data_2019_sports.Category]
# C:\Users\whfhr\AppData\Local\Temp\ipykernel_15620\2917215930.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2019_sports.Category = [s.replace("수", "") for s in data_2019_sports.Category]
# C:\Users\whfhr\AppData\Local\Temp\ipykernel_15620\2917215930.py:3: SettingWithCopyWarning:
# ...

# %%
df = [data_2019_sports, data_2020_sports, data_2021_sports, data_2022_sports]
data_sports = reduce(lambda left, right: pd.merge(left, right, on='Category'), df)
data_sports.columns = ["Category","2019", "2020", "2021", "2022"]
data_sports = pd.melt(data_sports, id_vars=['Category'], value_vars=['2019', '2020', '2021', '2022'])
data_sports = data_sports.rename(columns = {"variable" : "Year"})
# Out:
# C:\Users\whfhr\AppData\Local\Temp\ipykernel_15620\4127327147.py:2: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Value_x'} in the result is deprecated and will raise a MergeError in a future version.
#   data_sports = reduce(lambda left, right: pd.merge(left, right, on='Category'), df)

# %%
font_path  = "C:\Windows\Fonts\malgun.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

fig = plt.figure(figsize=(20,10))
sns.lineplot(x="Year", y="value",hue = "Category", data = data_sports, 
             marker='o', linewidth = 3)
plt.legend(fontsize = 16, loc = 'best' )
plt.xlabel("연도", fontsize = 16)
plt.ylabel("활동수", fontsize = 16)
plt.rc('ytick', labelsize=15) 
plt.rc('xtick', labelsize=15) 
plt.title("국민여가활동 - 스포츠", fontsize = 23)
# Out:
# Text(0.5, 1.0, '국민여가활동 - 스포츠')

# %%
# 문화 활동
data_2019_culture = data_2019[(data_2019.Category == "개인영화관람수") | 
                (data_2019.Category == "개인미술활동수") | (data_2019.Category == "개인생활공예활동수") |
                (data_2019.Category == "개인사진촬영수") |(data_2019.Category == "개인자연명소관람수") | 
                (data_2019.Category == "개인전시관람수") | (data_2019.Category == "개인전통예술학습활동수") | 
                (data_2019.Category == "개인문화유적방문수")|(data_2019.Category == "개인테마파크놀이공원동물원식물원방문수") | 
                (data_2019.Category == "개인박물관관람수") | (data_2019.Category == "개인지역축제참가수") | 
                (data_2019.Category == "개인전통예술공연관람수") | (data_2019.Category == "개인문학행사참여수") | 
                (data_2019.Category == "개인국내캠핑활동수")] 
data_2020_culture= data_2020[(data_2020.Category == "개인영화관람수") | 
                (data_2020.Category == "개인미술활동수") | (data_2020.Category == "개인생활공예활동수") |
                (data_2020.Category == "개인사진촬영수") |(data_2020.Category == "개인자연명소관람수") | 
                (data_2020.Category == "개인전시관람수") | (data_2020.Category == "개인전통예술학습활동수") | 
                (data_2020.Category == "개인문화유적방문수")|(data_2020.Category == "개인테마파크놀이공원동물원식물원방문수") | 
                (data_2020.Category == "개인박물관관람수") | (data_2020.Category == "개인지역축제참가수") | 
                (data_2020.Category == "개인전통예술공연관람수") | (data_2020.Category == "개인문학행사참여수") | 
                (data_2020.Category == "개인국내캠핑활동수")] 
data_2021_culture = data_2021[(data_2021.Category == "개인영화관람수") | 
                (data_2021.Category == "개인미술활동수") | (data_2021.Category == "개인생활공예활동수") |
                (data_2021.Category == "개인사진촬영수") |(data_2021.Category == "개인자연명소관람수") | 
                (data_2021.Category == "개인전시관람수") | (data_2021.Category == "개인전통예술학습활동수") | 
                (data_2021.Category == "개인문화유적방문수")|(data_2021.Category == "개인테마파크놀이공원동물원식물원방문수") | 
                (data_2021.Category == "개인박물관관람수") | (data_2021.Category == "개인지역축제참가수") | 
                (data_2021.Category == "개인전통예술공연관람수") | (data_2021.Category == "개인문학행사참여수") | 
                (data_2021.Category == "개인국내캠핑활동수")] 
data_2022_culture= data_2022[(data_2022.Category == "개인영화관람수") | 
                (data_2022.Category == "개인미술활동수") | (data_2022.Category == "개인생활공예활동수") |
                (data_2022.Category == "개인사진촬영수") |(data_2022.Category == "개인자연명소관람수") | 
                (data_2022.Category == "개인전시관람수") | (data_2022.Category == "개인전통예술학습활동수") | 
                (data_2022.Category == "개인문화유적방문수")|(data_2022.Category == "개인테마파크놀이공원동물원식물원방문수") | 
                (data_2022.Category == "개인박물관관람수") | (data_2022.Category == "개인지역축제참가수") | 
                (data_2022.Category == "개인전통예술공연관람수") | (data_2022.Category == "개인문학행사참여수") | 
                (data_2022.Category == "개인국내캠핑활동수")]

# %%
data_2019_culture.Category = [s.replace("개인", "") for s in data_2019_culture.Category]
data_2019_culture.Category = [s.replace("수", "") for s in data_2019_culture.Category]
data_2019_culture.Category = [s.replace("활동", "") for s in data_2019_culture.Category]
data_2020_culture.Category = [s.replace("개인", "") for s in data_2020_culture.Category]
data_2020_culture.Category = [s.replace("수", "") for s in data_2020_culture.Category]
data_2020_culture.Category = [s.replace("활동", "") for s in data_2020_culture.Category]
data_2021_culture.Category = [s.replace("개인", "") for s in data_2021_culture.Category]
data_2021_culture.Category = [s.replace("수", "") for s in data_2021_culture.Category]
data_2021_culture.Category = [s.replace("활동", "") for s in data_2021_culture.Category]
data_2022_culture.Category = [s.replace("개인", "") for s in data_2022_culture.Category]
data_2022_culture.Category = [s.replace("수", "") for s in data_2022_culture.Category]
data_2022_culture.Category = [s.replace("활동", "") for s in data_2022_culture.Category]
# Out:
# C:\Users\whfhr\AppData\Local\Temp\ipykernel_15620\1960838083.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2019_culture.Category = [s.replace("개인", "") for s in data_2019_culture.Category]
# C:\Users\whfhr\AppData\Local\Temp\ipykernel_15620\1960838083.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2019_culture.Category = [s.replace("수", "") for s in data_2019_culture.Category]
# C:\Users\whfhr\AppData\Local\Temp\ipykernel_15620\1960838083.py:3: SettingWithCopyWarning:
# ...

# %%
df = [data_2019_culture, data_2020_culture, data_2021_culture, data_2022_culture]
data_culture = reduce(lambda left, right: pd.merge(left, right, on='Category'), df)
data_culture.columns = ["Category","2019", "2020", "2021", "2022"]
data_culture = pd.melt(data_culture, id_vars=['Category'], value_vars=['2019', '2020', '2021', '2022'])
data_culture = data_culture.rename(columns = {"variable" : "Year"})
# Out:
# C:\Users\whfhr\AppData\Local\Temp\ipykernel_15620\487530858.py:2: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Value_x'} in the result is deprecated and will raise a MergeError in a future version.
#   data_culture = reduce(lambda left, right: pd.merge(left, right, on='Category'), df)

# %%
font_path  = "C:\Windows\Fonts\malgun.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

fig = plt.figure(figsize=(20,10))
sns.lineplot(x="Year", y="value",hue = "Category", data = data_culture, 
             marker='o', linewidth = 3)
plt.legend(fontsize = 16, loc = 'best' )
plt.xlabel("연도", fontsize = 16)
plt.ylabel("활동수", fontsize = 16)
plt.rc('ytick', labelsize=15) 
plt.rc('xtick', labelsize=15) 
plt.title("국민여가활동 - 문화생활", fontsize = 23)
# Out:
# Text(0.5, 1.0, '국민여가활동 - 문화생활')
